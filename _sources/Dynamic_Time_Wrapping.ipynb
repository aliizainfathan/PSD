# %% [markdown]
# # Dynamic Time Wrapping

# %% [markdown]
# Dynamic Time Warping (DTW) adalah sebuah algoritma untuk mengukur *kemiripan* antara dua deret waktu (*time series*)
# yang mungkin memiliki panjang berbeda atau kecepatan berbeda.
# DTW bekerja dengan mencari *alignment* terbaik antara dua sinyal sehingga total jarak antara titik-titik yang dibandingkan menjadi minimum.
#
# DTW sering dipakai pada:
# - Speech recognition
# - Analisis sinyal sensor
# - Motion tracking
# - Klasifikasi dan clustering time series

# %% [markdown]
# ## Library yang dibutuhkan

# %%
import librosa
import os
import pandas as pd
import numpy as np

# %% [markdown]
# ## Mengekstrak data time series dari data seara dengan label 'Buka' dan 'tutup'

# %%
folder = '/content/drive/MyDrive/data_PSD/data_suara_time_wrappping'

data_time_series = []
for i in os.listdir(folder):
  if i.endswith(('.wav', '.mp3')):
    path_file = os.path.join(folder, i)
    x, sr = librosa.load(path_file, sr = 4000)
    data_time_series.append(x)

# %% [markdown]
# ## Hasil 10 data time series yang dihasilkan

# %%
print("10 data pertama data time series suara")
for j in range (10):
  print(f"\n indeks ke- {j}, data = {data_time_series[j]}")
# Out:
# 10 data pertama data time series suara
#
#  indeks ke- 0, data = [6.4028427e-10 1.4551915e-10 4.0745363e-10 ... 7.3487044e-04 8.2284957e-04
#  9.0314628e-04]
#
#  indeks ke- 1, data = [ 5.8207661e-11  8.7311491e-11 -2.9103830e-11 ...  2.1789318e-04
#   3.8899285e-05 -4.7112429e-05]
#
#  indeks ke- 2, data = [-2.1827873e-11  0.0000000e+00 -7.2759576e-12 ... -3.8544822e-04
#  -3.1474186e-04 -4.0618455e-04]
#
#  indeks ke- 3, data = [ 1.4551915e-11 -2.1827873e-11  7.2759576e-12 ... -6.0990907e-04
#  -5.1070319e-04 -7.4119045e-04]
#
#  indeks ke- 4, data = [ 1.4551915e-11  4.3655746e-11  0.0000000e+00 ... -4.8730351e-04
#  -4.5495119e-04 -3.9114399e-04]
#
#  indeks ke- 5, data = [-3.6379788e-11 -1.4551915e-11 -1.4551915e-11 ...  3.2236252e-04
#   3.9786194e-04  5.8360019e-04]
#
#  indeks ke- 6, data = [ 0.0000000e+00  3.6379788e-11  1.4551915e-11 ...  3.7378886e-06
#  -9.0922724e-05 -1.5665835e-04]
#
#  indeks ke- 7, data = [-5.0931703e-11 -1.4551915e-11  5.8207661e-11 ...  1.8611464e-04
#   3.1201294e-04  5.5205508e-04]
#
#  indeks ke- 8, data = [ 2.91038305e-11  4.36557457e-11  4.36557457e-11 ...  1.84333490e-04
#   1.04201434e-04 -8.22195725e-05]
#
#  indeks ke- 9, data = [-7.2759576e-12  0.0000000e+00  7.2759576e-12 ... -1.9264885e-04
#   7.9774953e-05  2.2830974e-04]

# %% [markdown]
# ## Data Test

# %%
file_y = "/content/drive/MyDrive/data_PSD/test.mp3"

y, sr = librosa.load(file_y, sr = 4000)

print("data time series y = ", y)
print(len(y))
# Out:
# data time series y =  [-1.1641532e-10  5.8207661e-11  0.0000000e+00 ...  5.3613132e-04
#   6.1152177e-04  7.7914959e-04]
# 8736

# %% [markdown]
# ## Perhitungan Dynamic Time Wrapping

# %%
matrix_final = []
for i in range(len(data_time_series)):
  print("Proses Iterasi ke-", i)
  # data time series x
  x = data_time_series[i]

  # panjang setiap data time series
  panjang_x = len(data_time_series[i])
  panjang_y = len(y)

  n = panjang_x + 1
  m = panjang_y + 1

  # inisialisasi matrix akumulasi
  matrix_akumulasi = np.full((n, m), np.inf)
  matrix_akumulasi[0, 0] = 0

  # mengisi matrix akumulasi
  for l in range(panjang_x):
    for m in range(panjang_y):
      matrix_cost = (x[l] - y[m]) ** 2
      matrix_akumulasi[l + 1, m + 1] = matrix_cost + min(matrix_akumulasi[l, m],
                                           matrix_akumulasi[l, m + 1],
                                           matrix_akumulasi[l + 1, m])

  nilai_dwt = np.sqrt(matrix_akumulasi[panjang_x, panjang_y])
  matrix_final.append([i, nilai_dwt])
  print(f"proses iterasi ke- {i} selesai")
print(matrix_final)
# Out:
# Proses Iterasi ke- 0
# proses iterasi ke- 0 selesai
# Proses Iterasi ke- 1
# proses iterasi ke- 1 selesai
# Proses Iterasi ke- 2
# proses iterasi ke- 2 selesai
# Proses Iterasi ke- 3
# proses iterasi ke- 3 selesai
# Proses Iterasi ke- 4
# proses iterasi ke- 4 selesai
# Proses Iterasi ke- 5
# proses iterasi ke- 5 selesai
# Proses Iterasi ke- 6
# proses iterasi ke- 6 selesai
# Proses Iterasi ke- 7
# proses iterasi ke- 7 selesai
# Proses Iterasi ke- 8
# proses iterasi ke- 8 selesai
# Proses Iterasi ke- 9
# proses iterasi ke- 9 selesai
# Proses Iterasi ke- 10
# proses iterasi ke- 10 selesai
# Proses Iterasi ke- 11
# proses iterasi ke- 11 selesai
# Proses Iterasi ke- 12
# proses iterasi ke- 12 selesai
# Proses Iterasi ke- 13
# proses iterasi ke- 13 selesai
# Proses Iterasi ke- 14
# proses iterasi ke- 14 selesai
# Proses Iterasi ke- 15
# proses iterasi ke- 15 selesai
# Proses Iterasi ke- 16
# proses iterasi ke- 16 selesai
# Proses Iterasi ke- 17
# proses iterasi ke- 17 selesai
# Proses Iterasi ke- 18
# proses iterasi ke- 18 selesai
# Proses Iterasi ke- 19
# proses iterasi ke- 19 selesai
# Proses Iterasi ke- 20
# proses iterasi ke- 20 selesai
# Proses Iterasi ke- 21
# proses iterasi ke- 21 selesai
# Proses Iterasi ke- 22
# proses iterasi ke- 22 selesai
# Proses Iterasi ke- 23
# proses iterasi ke- 23 selesai
# Proses Iterasi ke- 24
# proses iterasi ke- 24 selesai
# Proses Iterasi ke- 25
# proses iterasi ke- 25 selesai
# Proses Iterasi ke- 26
# proses iterasi ke- 26 selesai
# Proses Iterasi ke- 27
# proses iterasi ke- 27 selesai
# Proses Iterasi ke- 28
# proses iterasi ke- 28 selesai
# Proses Iterasi ke- 29
# proses iterasi ke- 29 selesai
# Proses Iterasi ke- 30
# proses iterasi ke- 30 selesai
# Proses Iterasi ke- 31
# proses iterasi ke- 31 selesai
# Proses Iterasi ke- 32
# proses iterasi ke- 32 selesai
# Proses Iterasi ke- 33
# proses iterasi ke- 33 selesai
# Proses Iterasi ke- 34
# proses iterasi ke- 34 selesai
# Proses Iterasi ke- 35
# proses iterasi ke- 35 selesai
# Proses Iterasi ke- 36
# proses iterasi ke- 36 selesai
# Proses Iterasi ke- 37
# proses iterasi ke- 37 selesai
# Proses Iterasi ke- 38
# proses iterasi ke- 38 selesai
# Proses Iterasi ke- 39
# proses iterasi ke- 39 selesai
# Proses Iterasi ke- 40
# proses iterasi ke- 40 selesai
# Proses Iterasi ke- 41
# proses iterasi ke- 41 selesai
# Proses Iterasi ke- 42
# proses iterasi ke- 42 selesai
# Proses Iterasi ke- 43
# proses iterasi ke- 43 selesai
# Proses Iterasi ke- 44
# proses iterasi ke- 44 selesai
# Proses Iterasi ke- 45
# proses iterasi ke- 45 selesai
# Proses Iterasi ke- 46
# proses iterasi ke- 46 selesai
# Proses Iterasi ke- 47
# proses iterasi ke- 47 selesai
# Proses Iterasi ke- 48
# proses iterasi ke- 48 selesai
# Proses Iterasi ke- 49
# proses iterasi ke- 49 selesai
# Proses Iterasi ke- 50
# proses iterasi ke- 50 selesai
# Proses Iterasi ke- 51
# proses iterasi ke- 51 selesai
# Proses Iterasi ke- 52
# proses iterasi ke- 52 selesai
# Proses Iterasi ke- 53
# proses iterasi ke- 53 selesai
# Proses Iterasi ke- 54
# proses iterasi ke- 54 selesai
# Proses Iterasi ke- 55
# proses iterasi ke- 55 selesai
# Proses Iterasi ke- 56
# proses iterasi ke- 56 selesai
# Proses Iterasi ke- 57
# proses iterasi ke- 57 selesai
# Proses Iterasi ke- 58
# proses iterasi ke- 58 selesai
# Proses Iterasi ke- 59
# proses iterasi ke- 59 selesai
# Proses Iterasi ke- 60
# proses iterasi ke- 60 selesai
# Proses Iterasi ke- 61
# proses iterasi ke- 61 selesai
# Proses Iterasi ke- 62
# proses iterasi ke- 62 selesai
# Proses Iterasi ke- 63
# proses iterasi ke- 63 selesai
# Proses Iterasi ke- 64
# proses iterasi ke- 64 selesai
# Proses Iterasi ke- 65
# proses iterasi ke- 65 selesai
# Proses Iterasi ke- 66
# proses iterasi ke- 66 selesai
# Proses Iterasi ke- 67
# proses iterasi ke- 67 selesai
# Proses Iterasi ke- 68
# proses iterasi ke- 68 selesai
# Proses Iterasi ke- 69
# proses iterasi ke- 69 selesai
# Proses Iterasi ke- 70
# proses iterasi ke- 70 selesai
# Proses Iterasi ke- 71
# proses iterasi ke- 71 selesai
# Proses Iterasi ke- 72
# proses iterasi ke- 72 selesai
# Proses Iterasi ke- 73
# proses iterasi ke- 73 selesai
# Proses Iterasi ke- 74
# proses iterasi ke- 74 selesai
# Proses Iterasi ke- 75
# proses iterasi ke- 75 selesai
# Proses Iterasi ke- 76
# proses iterasi ke- 76 selesai
# Proses Iterasi ke- 77
# proses iterasi ke- 77 selesai
# Proses Iterasi ke- 78
# proses iterasi ke- 78 selesai
# Proses Iterasi ke- 79
# proses iterasi ke- 79 selesai
# Proses Iterasi ke- 80
# proses iterasi ke- 80 selesai
# Proses Iterasi ke- 81
# proses iterasi ke- 81 selesai
# Proses Iterasi ke- 82
# proses iterasi ke- 82 selesai
# Proses Iterasi ke- 83
# proses iterasi ke- 83 selesai
# Proses Iterasi ke- 84
# proses iterasi ke- 84 selesai
# Proses Iterasi ke- 85
# proses iterasi ke- 85 selesai
# Proses Iterasi ke- 86
# proses iterasi ke- 86 selesai
# Proses Iterasi ke- 87
# proses iterasi ke- 87 selesai
# Proses Iterasi ke- 88
# proses iterasi ke- 88 selesai
# Proses Iterasi ke- 89
# proses iterasi ke- 89 selesai
# Proses Iterasi ke- 90
# proses iterasi ke- 90 selesai
# Proses Iterasi ke- 91
# proses iterasi ke- 91 selesai
# Proses Iterasi ke- 92
# proses iterasi ke- 92 selesai
# Proses Iterasi ke- 93
# proses iterasi ke- 93 selesai
# Proses Iterasi ke- 94
# proses iterasi ke- 94 selesai
# Proses Iterasi ke- 95
# proses iterasi ke- 95 selesai
# Proses Iterasi ke- 96
# proses iterasi ke- 96 selesai
# Proses Iterasi ke- 97
# proses iterasi ke- 97 selesai
# Proses Iterasi ke- 98
# proses iterasi ke- 98 selesai
# Proses Iterasi ke- 99
# proses iterasi ke- 99 selesai
# Proses Iterasi ke- 100
# proses iterasi ke- 100 selesai
# Proses Iterasi ke- 101
# proses iterasi ke- 101 selesai
# Proses Iterasi ke- 102
# proses iterasi ke- 102 selesai
# Proses Iterasi ke- 103
# proses iterasi ke- 103 selesai
# Proses Iterasi ke- 104
# proses iterasi ke- 104 selesai
# Proses Iterasi ke- 105
# proses iterasi ke- 105 selesai
# Proses Iterasi ke- 106
# proses iterasi ke- 106 selesai
# Proses Iterasi ke- 107
# proses iterasi ke- 107 selesai
# Proses Iterasi ke- 108
# proses iterasi ke- 108 selesai
# Proses Iterasi ke- 109
# proses iterasi ke- 109 selesai
# Proses Iterasi ke- 110
# proses iterasi ke- 110 selesai
# Proses Iterasi ke- 111
# proses iterasi ke- 111 selesai
# Proses Iterasi ke- 112
# proses iterasi ke- 112 selesai
# Proses Iterasi ke- 113
# proses iterasi ke- 113 selesai
# Proses Iterasi ke- 114
# proses iterasi ke- 114 selesai
# Proses Iterasi ke- 115
# proses iterasi ke- 115 selesai
# Proses Iterasi ke- 116
# proses iterasi ke- 116 selesai
# Proses Iterasi ke- 117
# proses iterasi ke- 117 selesai
# Proses Iterasi ke- 118
# proses iterasi ke- 118 selesai
# Proses Iterasi ke- 119
# proses iterasi ke- 119 selesai
# Proses Iterasi ke- 120
# proses iterasi ke- 120 selesai
# Proses Iterasi ke- 121
# proses iterasi ke- 121 selesai
# Proses Iterasi ke- 122
# proses iterasi ke- 122 selesai
# Proses Iterasi ke- 123
# proses iterasi ke- 123 selesai
# Proses Iterasi ke- 124
# proses iterasi ke- 124 selesai
# Proses Iterasi ke- 125
# proses iterasi ke- 125 selesai
# Proses Iterasi ke- 126
# proses iterasi ke- 126 selesai
# Proses Iterasi ke- 127
# proses iterasi ke- 127 selesai
# Proses Iterasi ke- 128
# proses iterasi ke- 128 selesai
# Proses Iterasi ke- 129
# proses iterasi ke- 129 selesai
# Proses Iterasi ke- 130
# proses iterasi ke- 130 selesai
# Proses Iterasi ke- 131
# proses iterasi ke- 131 selesai
# Proses Iterasi ke- 132
# proses iterasi ke- 132 selesai
# Proses Iterasi ke- 133
# proses iterasi ke- 133 selesai
# Proses Iterasi ke- 134
# proses iterasi ke- 134 selesai
# Proses Iterasi ke- 135
# proses iterasi ke- 135 selesai
# Proses Iterasi ke- 136
# proses iterasi ke- 136 selesai
# Proses Iterasi ke- 137
# proses iterasi ke- 137 selesai
# Proses Iterasi ke- 138
# proses iterasi ke- 138 selesai
# Proses Iterasi ke- 139
# proses iterasi ke- 139 selesai
# Proses Iterasi ke- 140
# proses iterasi ke- 140 selesai
# Proses Iterasi ke- 141
# proses iterasi ke- 141 selesai
# Proses Iterasi ke- 142
# proses iterasi ke- 142 selesai
# Proses Iterasi ke- 143
# proses iterasi ke- 143 selesai
# Proses Iterasi ke- 144
# proses iterasi ke- 144 selesai
# Proses Iterasi ke- 145
# proses iterasi ke- 145 selesai
# Proses Iterasi ke- 146
# proses iterasi ke- 146 selesai
# Proses Iterasi ke- 147
# proses iterasi ke- 147 selesai
# Proses Iterasi ke- 148
# proses iterasi ke- 148 selesai
# Proses Iterasi ke- 149
# proses iterasi ke- 149 selesai
# Proses Iterasi ke- 150
# proses iterasi ke- 150 selesai
# Proses Iterasi ke- 151
# proses iterasi ke- 151 selesai
# Proses Iterasi ke- 152
# proses iterasi ke- 152 selesai
# Proses Iterasi ke- 153
# proses iterasi ke- 153 selesai
# Proses Iterasi ke- 154
# proses iterasi ke- 154 selesai
# Proses Iterasi ke- 155
# proses iterasi ke- 155 selesai
# Proses Iterasi ke- 156
# proses iterasi ke- 156 selesai
# Proses Iterasi ke- 157
# proses iterasi ke- 157 selesai
# Proses Iterasi ke- 158
# proses iterasi ke- 158 selesai
# Proses Iterasi ke- 159
# proses iterasi ke- 159 selesai
# Proses Iterasi ke- 160
# proses iterasi ke- 160 selesai
# Proses Iterasi ke- 161
# proses iterasi ke- 161 selesai
# Proses Iterasi ke- 162
# proses iterasi ke- 162 selesai
# Proses Iterasi ke- 163
# proses iterasi ke- 163 selesai
# Proses Iterasi ke- 164
# proses iterasi ke- 164 selesai
# Proses Iterasi ke- 165
# proses iterasi ke- 165 selesai
# Proses Iterasi ke- 166
# proses iterasi ke- 166 selesai
# Proses Iterasi ke- 167
# proses iterasi ke- 167 selesai
# Proses Iterasi ke- 168
# proses iterasi ke- 168 selesai
# Proses Iterasi ke- 169
# proses iterasi ke- 169 selesai
# Proses Iterasi ke- 170
# proses iterasi ke- 170 selesai
# Proses Iterasi ke- 171
# proses iterasi ke- 171 selesai
# Proses Iterasi ke- 172
# proses iterasi ke- 172 selesai
# Proses Iterasi ke- 173
# proses iterasi ke- 173 selesai
# Proses Iterasi ke- 174
# proses iterasi ke- 174 selesai
# Proses Iterasi ke- 175
# proses iterasi ke- 175 selesai
# Proses Iterasi ke- 176
# proses iterasi ke- 176 selesai
# Proses Iterasi ke- 177
# proses iterasi ke- 177 selesai
# Proses Iterasi ke- 178
# proses iterasi ke- 178 selesai
# Proses Iterasi ke- 179
# proses iterasi ke- 179 selesai
# Proses Iterasi ke- 180
# proses iterasi ke- 180 selesai
# Proses Iterasi ke- 181
# proses iterasi ke- 181 selesai
# Proses Iterasi ke- 182
# proses iterasi ke- 182 selesai
# Proses Iterasi ke- 183
# proses iterasi ke- 183 selesai
# Proses Iterasi ke- 184
# proses iterasi ke- 184 selesai
# Proses Iterasi ke- 185
# proses iterasi ke- 185 selesai
# Proses Iterasi ke- 186
# proses iterasi ke- 186 selesai
# Proses Iterasi ke- 187
# proses iterasi ke- 187 selesai
# Proses Iterasi ke- 188
# proses iterasi ke- 188 selesai
# Proses Iterasi ke- 189
# proses iterasi ke- 189 selesai
# Proses Iterasi ke- 190
# proses iterasi ke- 190 selesai
# Proses Iterasi ke- 191
# proses iterasi ke- 191 selesai
# Proses Iterasi ke- 192
# proses iterasi ke- 192 selesai
# Proses Iterasi ke- 193
# proses iterasi ke- 193 selesai
# Proses Iterasi ke- 194
# proses iterasi ke- 194 selesai
# Proses Iterasi ke- 195
# proses iterasi ke- 195 selesai
# Proses Iterasi ke- 196
# proses iterasi ke- 196 selesai
# Proses Iterasi ke- 197
# proses iterasi ke- 197 selesai
# Proses Iterasi ke- 198
# proses iterasi ke- 198 selesai
# Proses Iterasi ke- 199
# proses iterasi ke- 199 selesai
# [[0, np.float64(2.3277324383474234)], [1, np.float64(2.285439958765221)], [2, np.float64(2.9208939969009693)], [3, np.float64(3.2182455901021054)], [4, np.float64(3.31206854135007)], [5, np.float64(2.6836438503501716)], [6, np.float64(2.8886372751105642)], [7, np.float64(3.1307778532462254)], [8, np.float64(3.312537657880684)], [9, np.float64(3.5183104596360857)], [10, np.float64(3.689102454367805)], [11, np.float64(3.9800422149787438)], [12, np.float64(3.923239869317818)], [13, np.float64(4.220388176525509)], [14, np.float64(3.984002467873207)], [15, np.float64(4.25420372664838)], [16, np.float64(4.158424402474599)], [17, np.float64(4.013194409790969)], [18, np.float64(4.146949949056836)], [19, np.float64(4.243490312067787)], [20, np.float64(3.7905814885188023)], [21, np.float64(3.8782254011166994)], [22, np.float64(4.16155103104739)], [23, np.float64(4.199914461483816)], [24, np.float64(3.899319126393814)], [25, np.float64(3.9629346041743077)], [26, np.float64(4.264204265392749)], [27, np.float64(4.205174112163949)], [28, np.float64(4.201176065763057)], [29, np.float64(4.191314803307133)], [30, np.float64(4.297464403828622)], [31, np.float64(3.553284647464119)], [32, np.float64(4.165245308335113)], [33, np.float64(4.326078048944187)], [34, np.float64(3.782676446313269)], [35, np.float64(3.7048448901163273)], [36, np.float64(3.9350876558428776)], [37, np.float64(3.9670256790010248)], [38, np.float64(3.80880514921502)], [39, np.float64(4.067368786776174)], [40, np.float64(4.38459134518594)], [41, np.float64(4.10667477070107)], [42, np.float64(3.8187192069033915)], [43, np.float64(3.718823971220277)], [44, np.float64(4.053012668055611)], [45, np.float64(3.9774099777797707)], [46, np.float64(4.067677640947397)], [47, np.float64(4.126643393602802)], [48, np.float64(4.180794362034623)], [49, np.float64(3.9279852467246203)], [50, np.float64(3.6917962561284305)], [51, np.float64(3.935883559279984)], [52, np.float64(3.579890368029975)], [53, np.float64(3.588033153300932)], [54, np.float64(3.833613974036969)], [55, np.float64(3.998843411563069)], [56, np.float64(4.101655290362898)], [57, np.float64(3.5222394824931214)], [58, np.float64(3.9664007431951673)], [59, np.float64(4.007927771354259)], [60, np.float64(3.8150095632859786)], [61, np.float64(3.8991923093446275)], [62, np.float64(3.9533921459267307)], [63, np.float64(4.054220398515477)], [64, np.float64(4.04105483992484)], [65, np.float64(4.17209824498414)], [66, np.float64(3.825459523300755)], [67, np.float64(4.146370789316006)], [68, np.float64(3.7659202778434095)], [69, np.float64(4.320936380402184)], [70, np.float64(3.6678932072485892)], [71, np.float64(4.046660177463136)], [72, np.float64(4.045925754980025)], [73, np.float64(4.071069063365194)], [74, np.float64(4.29242583367423)], [75, np.float64(4.054810340192847)], [76, np.float64(4.116467735847339)], [77, np.float64(4.286834833754183)], [78, np.float64(3.9861681581525343)], [79, np.float64(4.175058067835156)], [80, np.float64(4.046458064208782)], [81, np.float64(4.1329018135349616)], [82, np.float64(4.379149520571387)], [83, np.float64(4.226573885356072)], [84, np.float64(3.977480535362717)], [85, np.float64(3.999280724508174)], [86, np.float64(3.7918361057688377)], [87, np.float64(4.000758436550542)], [88, np.float64(4.052070603337472)], [89, np.float64(4.00382622952601)], [90, np.float64(4.188998515990488)], [91, np.float64(4.280551142021861)], [92, np.float64(4.2809798564947386)], [93, np.float64(4.394315010717635)], [94, np.float64(4.244904471973181)], [95, np.float64(4.291935606240436)], [96, np.float64(4.39323113231232)], [97, np.float64(4.302935902703064)], [98, np.float64(4.328708469585393)], [99, np.float64(4.183194626736848)], [100, np.float64(4.203735461730391)], [101, np.float64(4.5988007488309295)], [102, np.float64(4.519173509059657)], [103, np.float64(4.356832139008057)], [104, np.float64(4.340669798304871)], [105, np.float64(4.175112949805577)], [106, np.float64(3.8470226700243044)], [107, np.float64(4.3767 ...

# %% [markdown]
# ## Menambahkan label berdasarkan real dataset

# %%
for i in range(200):
  if i <= 99:
    matrix_final[i].append('buka')
  else:
    matrix_final[i].append('tutup')

# %% [markdown]
# ## Mengurutkan Nilai DWT

# %%
data_urut = sorted(matrix_final, key=lambda x: x[1])
print(data_urut)
# Out:
# [[1, np.float64(2.285439958765221), 'buka'], [0, np.float64(2.3277324383474234), 'buka'], [5, np.float64(2.6836438503501716), 'buka'], [6, np.float64(2.8886372751105642), 'buka'], [2, np.float64(2.9208939969009693), 'buka'], [7, np.float64(3.1307778532462254), 'buka'], [3, np.float64(3.2182455901021054), 'buka'], [4, np.float64(3.31206854135007), 'buka'], [8, np.float64(3.312537657880684), 'buka'], [9, np.float64(3.5183104596360857), 'buka'], [57, np.float64(3.5222394824931214), 'buka'], [31, np.float64(3.553284647464119), 'buka'], [52, np.float64(3.579890368029975), 'buka'], [53, np.float64(3.588033153300932), 'buka'], [70, np.float64(3.6678932072485892), 'buka'], [10, np.float64(3.689102454367805), 'buka'], [50, np.float64(3.6917962561284305), 'buka'], [35, np.float64(3.7048448901163273), 'buka'], [43, np.float64(3.718823971220277), 'buka'], [193, np.float64(3.7528677701114908), 'tutup'], [68, np.float64(3.7659202778434095), 'buka'], [34, np.float64(3.782676446313269), 'buka'], [20, np.float64(3.7905814885188023), 'buka'], [86, np.float64(3.7918361057688377), 'buka'], [38, np.float64(3.80880514921502), 'buka'], [60, np.float64(3.8150095632859786), 'buka'], [42, np.float64(3.8187192069033915), 'buka'], [66, np.float64(3.825459523300755), 'buka'], [54, np.float64(3.833613974036969), 'buka'], [162, np.float64(3.8431714215281514), 'tutup'], [106, np.float64(3.8470226700243044), 'tutup'], [185, np.float64(3.8641592311533897), 'tutup'], [171, np.float64(3.8675238680005624), 'tutup'], [21, np.float64(3.8782254011166994), 'buka'], [61, np.float64(3.8991923093446275), 'buka'], [24, np.float64(3.899319126393814), 'buka'], [12, np.float64(3.923239869317818), 'buka'], [49, np.float64(3.9279852467246203), 'buka'], [36, np.float64(3.9350876558428776), 'buka'], [51, np.float64(3.935883559279984), 'buka'], [108, np.float64(3.939171907358673), 'tutup'], [62, np.float64(3.9533921459267307), 'buka'], [173, np.float64(3.959472220336147), 'tutup'], [25, np.float64(3.9629346041743077), 'buka'], [58, np.float64(3.9664007431951673), 'buka'], [37, np.float64(3.9670256790010248), 'buka'], [45, np.float64(3.9774099777797707), 'buka'], [84, np.float64(3.977480535362717), 'buka'], [11, np.float64(3.9800422149787438), 'buka'], [14, np.float64(3.984002467873207), 'buka'], [78, np.float64(3.9861681581525343), 'buka'], [169, np.float64(3.990170122952228), 'tutup'], [166, np.float64(3.99557426436352), 'tutup'], [55, np.float64(3.998843411563069), 'buka'], [85, np.float64(3.999280724508174), 'buka'], [87, np.float64(4.000758436550542), 'buka'], [89, np.float64(4.00382622952601), 'buka'], [59, np.float64(4.007927771354259), 'buka'], [178, np.float64(4.010659882426062), 'tutup'], [17, np.float64(4.013194409790969), 'buka'], [165, np.float64(4.01324807989708), 'tutup'], [156, np.float64(4.023689546491389), 'tutup'], [64, np.float64(4.04105483992484), 'buka'], [72, np.float64(4.045925754980025), 'buka'], [191, np.float64(4.046424687584321), 'tutup'], [80, np.float64(4.046458064208782), 'buka'], [71, np.float64(4.046660177463136), 'buka'], [88, np.float64(4.052070603337472), 'buka'], [44, np.float64(4.053012668055611), 'buka'], [63, np.float64(4.054220398515477), 'buka'], [75, np.float64(4.054810340192847), 'buka'], [39, np.float64(4.067368786776174), 'buka'], [46, np.float64(4.067677640947397), 'buka'], [73, np.float64(4.071069063365194), 'buka'], [194, np.float64(4.080958347322267), 'tutup'], [157, np.float64(4.093557418501295), 'tutup'], [145, np.float64(4.100937379302941), 'tutup'], [56, np.float64(4.101655290362898), 'buka'], [192, np.float64(4.102557341605845), 'tutup'], [41, np.float64(4.10667477070107), 'buka'], [190, np.float64(4.11028909931946), 'tutup'], [175, np.float64(4.111226126731706), 'tutup'], [76, np.float64(4.116467735847339), 'buka'], [179, np.float64(4.117784770873533), 'tutup'], [143, np.float64(4.123936642182685), 'tutup'], [47, np.float64(4.126643393602802), 'buka'], [81, np.float64(4.1329018135349616), 'buka'], [177, np.float64(4.13998314 ...

# %% [markdown]
# ## Kesimpulan

# %% [markdown]
# ### Label Data Test Berdasarkan Nilai DWT Terendah

# %%
print(data_urut[0])
# Out:
# [1, np.float64(2.285439958765221), 'buka']

# %% [markdown]
# Berdasarkan hal tersebut dapat disimpulkan bahwa data test memiliki label buka, dengan nilai DWT terhadap data index 1 yakni sebesar 2.285439958765221.
